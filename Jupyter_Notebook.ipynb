# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Williams Afriyie, Owusu__
#     Agronomist

# %% [markdown]
# _I am interested in Data Science because I would like to provide Farmers with valuable insights that will save them from the high cost of production, thereby enhancing their profitability and income_

# %% [markdown]
# ### This code prints Hello Friend

# %%
print('Hello Friend')
# Out:
# Hello Friend

# %% [markdown]
# # Horizontal rule:
# ****
#
# # Bulleted list:
# - bullet-1
# - bullet-2
# - bullet-3
#
# # Numbered list:
# 1. number_one
# 2. number_two
# 3. number_three
#
# # Hyperlinks:
# [Click here to Github](https://www.github.com/)
